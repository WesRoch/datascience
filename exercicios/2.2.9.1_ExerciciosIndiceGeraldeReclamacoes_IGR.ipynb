# %% [markdown]
# http://dados.gov.br/dataset/indice-de-reclamacoes
#
# O IGR têm como base os dados de beneficiários e reclamações recebidos pela ANS e permitem comparar a atuação das empresas que atuam no setor de Saúde Suplementar.
#
# Gráficos, Link abaixo:
#
# http://www.ans.gov.br/planos-de-saude-e-operadoras/informacoes-e-avaliacoes-de-operadoras/indice-de-reclamacoes/indice-geral-de-reclamacoes-igr
#
# Tem como principal finalidade apresentar um termômetro do comportamento das operadoras do setor no atendimento aos problemas apontados pelos beneficiários. Contempla o número médio de reclamações de beneficiários recebidas nos três meses anteriores e classificadas até a data de extração do dado. O índice tem como referência cada 10.000 beneficiários do universo de consumidores analisado.

# %%
import pandas as pd

# %%
igr = pd.read_csv("CSV/igr_anual_csv/igr.csv", sep=';', encoding='UTF-8')
igr2015 = pd.read_csv("CSV/igr_anual_csv/IGR_2015.csv", sep=';', encoding='ISO-8859-1')
igr2016 = pd.read_csv("CSV/igr_anual_csv/IGR_2016.csv", sep=';', encoding='ISO-8859-1')
igr2017 = pd.read_csv("CSV/igr_anual_csv/IGR_2017.csv", sep=';', encoding='ISO-8859-1')
igr2018 = pd.read_csv("CSV/igr_anual_csv/IGR_2018.csv", sep=';', encoding='ISO-8859-1')

# %%
igr.head()
# Out:
#                          Raz�o Social (Registro ANS)          Cobertura  \
# 0  ABERTTA SA�DE - ASSOCIA��O BENEFICENTE DOS EMP...  M�dico Hospitalar
# 1              ADVANCE PLANOS DE SA�DE LTDA (335657)  M�dico Hospitalar
# 2                         AGEMED SA�DE S.A. (339601)  M�dico Hospitalar
# 3  AGROS - INSTITUTO UFV DE SEGURIDADE SOCIAL (36...  M�dico Hospitalar
# 4                       ALCANCE SA�DE LTDA. (416975)  M�dico Hospitalar
#
#      Porte  Classifica��o no M�s  Classifica��o no M�s Anterior   set/19  \
# 0    M�dio                   211                          220.0     0,27
# 1  Pequeno                    47                           29.0     6,89
# 2   Grande                     1                            2.0    36,15
# 3  Pequeno                   176                          189.0     0,64
# 4  Pequeno                   185                          197.0     0,00
#
#     ago/19   jul/19   jun/19   mai/19   abr/19   mar/19   fev/19   jan/19  \
# ...

# %%
igr2015.head()
# Out:
#                          Razão Social (Registro ANS)          Cobertura  \
# 0  ABERTTA SAÚDE - ASSOCIAÇÃO BENEFICENTE DOS EMP...  Médico Hospitalar
# 1              ADVANCE PLANOS DE SAÚDE LTDA (335657)  Médico Hospitalar
# 2                         AGEMED SAÚDE S.A. (339601)  Médico Hospitalar
# 3  AGROS - INSTITUTO UFV DE SEGURIDADE SOCIAL (36...  Médico Hospitalar
# 4                         ALLIANZ SAÚDE S/A (000515)  Médico Hospitalar
#
#      Porte  Classificação no Mês  Classificação no Mês Anterior  dez/15  \
# 0  Pequeno                   NaN                            NaN     NaN
# 1  Pequeno                  97.0                          113.0   80,00
# 2   Grande                  69.0                           76.0   92,31
# 3  Pequeno                   NaN                            NaN     NaN
# 4    Médio                   1.0                            1.0  100,00
#
#    nov/15  out/15  set/15  ago/15  jul/15  jun/15  mai/15  abr/15  mar/15  \
# ...

# %%
igr2016.head()
# Out:
#                         RazÃ£o Social (Registro ANS)           Cobertura  \
# 0  ABERTTA SAÃDE - ASSOCIAÃÃO BENEFICENTE DOS ...  MÃ©dico Hospitalar
# 1             ADVANCE PLANOS DE SAÃDE LTDA (335657)  MÃ©dico Hospitalar
# 2                        AGEMED SAÃDE S.A. (339601)  MÃ©dico Hospitalar
# 3  AGROS - INSTITUTO UFV DE SEGURIDADE SOCIAL (36...  MÃ©dico Hospitalar
# 4                        ALLIANZ SAÃDE S/A (000515)  MÃ©dico Hospitalar
#
#      Porte  ClassificaÃ§Ã£o no MÃªs  ClassificaÃ§Ã£o no MÃªs Anterior  dez/16  \
# 0  Pequeno                      NaN                               NaN     NaN
# 1  Pequeno                      1.0                               1.0  100,00
# 2   Grande                     72.0                              72.0   85,00
# 3  Pequeno                      NaN                               NaN     NaN
# 4   MÃ©dio                      1.0                               1.0  100,00
#
# ...

# %%
igr2017.head()
# Out:
#                          Razão Social (Registro ANS)          Cobertura  \
# 0  ABERTTA SAÚDE - ASSOCIAÇÃO BENEFICENTE DOS EMP...  Médico Hospitalar
# 1              ADVANCE PLANOS DE SAÚDE LTDA (335657)  Médico Hospitalar
# 2                         AGEMED SAÚDE S.A. (339601)  Médico Hospitalar
# 3  AGROS - INSTITUTO UFV DE SEGURIDADE SOCIAL (36...  Médico Hospitalar
# 4                         ALLIANZ SAÚDE S/A (000515)  Médico Hospitalar
#
#      Porte  Classificação no Mês  Classificação no Mês Anterior dez/17  \
# 0    Médio                   NaN                            NaN    NaN
# 1  Pequeno                   NaN                            1.0    NaN
# 2   Grande                  74.0                           77.0  79,55
# 3  Pequeno                   NaN                            NaN    NaN
# 4    Médio                 135.0                          155.0  92,00
#
#    nov/17  out/17  set/17  ago/17  jul/17 jun/17 mai/17  abr/17  mar/17  \
# ...
